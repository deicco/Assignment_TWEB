# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import self
plt.style.use('ggplot')

# %% [markdown]
# Reading CSV and creation dataframe

# %%
df_actors = pd.read_csv('C:\\Users\\Windows11\\Desktop\\dataset\\actors.csv')

# %% [markdown]
# Checking CSV dimension

# %%
df_actors.shape
# Out:
# (5798450, 3)

# %% [markdown]
# Showing CSV line

# %%
df_actors.head(5)
# Out:
#         id               name    role
# 0  1000001      Margot Robbie  Barbie
# 1  1000001       Ryan Gosling     Ken
# 2  1000001    America Ferrera  Gloria
# 3  1000001  Ariana Greenblatt   Sasha
# 4  1000001           Issa Rae  Barbie

# %% [markdown]
# Showing CSV index

# %%
df_actors.columns
# Out:
# Index(['id', 'name', 'role'], dtype='object')

# %% [markdown]
# Showing CSV columns types

# %%
df_actors.dtypes
# Out:
# id       int64
# name    object
# role    object
# dtype: object

# %% [markdown]
# Obtaining a statistical summary of the numerical columns of the CSV DataFrame

# %%
df_actors.describe()
# Out:
#                  id
# count  5.798450e+06
# mean   1.302557e+06
# std    2.551917e+05
# min    1.000001e+06
# 25%    1.079557e+06
# 50%    1.236225e+06
# 75%    1.483358e+06
# max    1.941597e+06

# %% [markdown]
# Show the first few rows of the dataframe

# %%
df_actors.head()
# Out:
#         id               name    role
# 0  1000001      Margot Robbie  Barbie
# 1  1000001       Ryan Gosling     Ken
# 2  1000001    America Ferrera  Gloria
# 3  1000001  Ariana Greenblatt   Sasha
# 4  1000001           Issa Rae  Barbie

# %% [markdown]
# Identify missing values or null values

# %%
df_actors.isna()
# Out:
#             id   name   role
# 0        False  False  False
# 1        False  False  False
# 2        False  False  False
# 3        False  False  False
# 4        False  False  False
# ...        ...    ...    ...
# 5798445  False  False  False
# 5798446  False  False  False
# 5798447  False  False  False
# 5798448  False  False   True
# 5798449  False  False   True
#
# [5798450 rows x 3 columns]

# %% [markdown]
# Showing the sum of the number of null values per columns

# %%
df_actors.isna().sum()
# Out:
# id            0
# name          4
# role    1361559
# dtype: int64

# %% [markdown]
# Showing if any of our data is duplicated

# %%
df_actors.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 5798445    False
# 5798446    False
# 5798447    False
# 5798448    False
# 5798449    False
# Length: 5798450, dtype: bool

# %% [markdown]
# Returns a new DataFrame containing only the rows that are duplicated

# %%
df_actors.loc[df_actors.duplicated(subset = 'id')]
# Out:
#               id               name                 role
# 1        1000001       Ryan Gosling                  Ken
# 2        1000001    America Ferrera               Gloria
# 3        1000001  Ariana Greenblatt                Sasha
# 4        1000001           Issa Rae               Barbie
# 5        1000001      Kate McKinnon               Barbie
# ...          ...                ...                  ...
# 5798444  1941596     Sandrine Pinna                  NaN
# 5798445  1941596            Marc Ma            Ba Cai/巴莱
# 5798446  1941596                线雨轩              Tata/塔塔
# 5798447  1941596       Jiang Yixuan  Zuo Yila（Zoila）/佐伊拉
# 5798449  1941597      Keiko Oginome                  NaN
#
# [5164148 rows x 3 columns]

# %%
df_actors.loc[df_actors.duplicated(subset='name')]
# Out:
#               id            name                 role
# 327      1000005    Ryan Gosling            Sebastian
# 604      1000007   Casey Affleck           Tom Cooper
# 613      1000007      Matt Damon                 Mann
# 623      1000007    Jeff Hephner               Doctor
# 628      1000007     Flora Nolan        Girl on Truck
# ...          ...             ...                  ...
# 5798444  1941596  Sandrine Pinna                  NaN
# 5798445  1941596         Marc Ma            Ba Cai/巴莱
# 5798447  1941596    Jiang Yixuan  Zuo Yila（Zoila）/佐伊拉
# 5798448  1941597  Hiroshi Mikami                  NaN
# 5798449  1941597   Keiko Oginome                  NaN
#
# [4197787 rows x 3 columns]

# %%
df_actors.loc[df_actors.duplicated(subset='role')]
# Out:
#               id             name    role
# 4        1000001         Issa Rae  Barbie
# 5        1000001    Kate McKinnon  Barbie
# 6        1000001  Alexandra Shipp  Barbie
# 7        1000001      Emma Mackey  Barbie
# 8        1000001         Hari Nef  Barbie
# ...          ...              ...     ...
# 5798439  1941563         Lan Xiya     NaN
# 5798440  1941563             黄子弘凡     NaN
# 5798444  1941596   Sandrine Pinna     NaN
# 5798448  1941597   Hiroshi Mikami     NaN
# 5798449  1941597    Keiko Oginome     NaN
#
# [3878364 rows x 3 columns]

# %% [markdown]
# Query on columns

# %%
df_actors.query('id == 1020695')
# Out:
#              id               name                     role
# 584993  1020695      Burt Reynolds          Lt. Phil Gaines
# 584994  1020695  Catherine Deneuve           Nicole Britton
# 584995  1020695        Ben Johnson          Marty Hollinger
# 584996  1020695      Paul Winfield           Louis Belgrave
# 584997  1020695     Eileen Brennan          Paula Hollinger
# 584998  1020695       Eddie Albert              Leo Sellers
# 584999  1020695    Ernest Borgnine                  Santuro
# 585000  1020695     Catherine Bach            Peggy Summers
# 585001  1020695        Jack Carter            Herbie Dalitz
# 585002  1020695      James Hampton               Bus Driver
# 585003  1020695    Colleen Brennan         Gloria Hollinger
# 585004  1020695      Chuck Hayward         Morgue Attendant
# 585005  1020695     David Estridge                   Albino
# 585006  1020695      Peter Brandon                 Minister
# 585007  1020695    David Spielberg            Jerry Bellamy
# ...

# %%
df_actors.query('name == "Natalie Portman"')
# Out:
#               id             name                                role
# 2409     1000035  Natalie Portman        Nina Sayers / The Swan Queen
# 2968     1000043  Natalie Portman                         Jane Foster
# 11712    1000188  Natalie Portman                       Padmé Amidala
# 12264    1000197  Natalie Portman       Jane Foster / The Mighty Thor
# 13726    1000223  Natalie Portman                       Padmé Amidala
# ...          ...              ...                                 ...
# 1935457  1123663  Natalie Portman  Pauline Friedman / Esther Friedman
# 2019620  1132227  Natalie Portman                             (voice)
# 2251809  1156644  Natalie Portman                                Self
# 2441727  1178241  Natalie Portman                              Ronnie
# 3021631  1253344  Natalie Portman                   Dominique Bellamy
#
# [64 rows x 3 columns]

# %%
df_actors.query('role == "Policeman"')
# Out:
#               id               name       role
# 55       1000001      Carlos Jacott  Policeman
# 56       1000001           Adam Ray  Policeman
# 293      1000004  David Jean Thomas  Policeman
# 2350     1000033     Michael Graham  Policeman
# 2398     1000034     Burnell Tucker  Policeman
# ...          ...                ...        ...
# 5729186  1897519         Nick Nysum  Policeman
# 5735546  1901218      William Ellis  Policeman
# 5783422  1933408      Thomas Runkel  Policeman
# 5787660  1935528    Craig Colasanti  Policeman
# 5790504  1937032       Abe Ginsberg  Policeman
#
# [3577 rows x 3 columns]
